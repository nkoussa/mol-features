# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

import os
import sys
from pathlib import Path
from time import time
import numpy as np
import pandas as pd
from glob import glob
import matplotlib
import matplotlib.pyplot as plt
print(Path.cwd())

# %%
def sizeof(data, verbose=True):
    sz = sys.getsizeof(data)/1e9
    if verbose: print(f'Size in GB: {sz}')
    return sz

# %%
fea_main_dir = Path('/vol/ml/apartin/projects/covid-19/mol-features/data/raw/OZD-Kyle/')
fea_type = 'descriptors'
fea_dir = fea_main_dir/fea_type
fea_files = sorted( fea_dir.glob('OZD-*.csv') )
print(len(fea_files))
# Out:
# 668

# %% [markdown]
# # Load descriptors

# %%
dd_prfx = 'dd'
dd_sep = '_'

# %%
fea_col_names = pd.read_csv(fea_main_dir/'headers.csv').columns.tolist()
fea_col_names = [c.strip() for c in fea_col_names] # clean col names
print(fea_col_names[:3])
print(len(fea_col_names))
# Out:
# ['ABC', 'ABCGG', 'nAcid']
# 1826

# %%
fea_col_names = [dd_prfx+dd_sep+str(c) for c in fea_col_names] # prefix fea cols
cols = ['CAT', 'TITLE', 'SMILES'] + fea_col_names

# %% [markdown]
# # Load single fea df

# %%
dd0 = pd.read_csv( Path(fea_files[0]), names=cols )
print(dd0.shape)
print('Expected size when including drugs', sizeof(dd0, verbose=False) * len(fea_files))
display(dd0[:2])
# Out:
# (10000, 1829)
# Size in GB: 0.148535416
#    CAT             TITLE                                             SMILES  \
# 0  OZD  ZINC000095370606  Cc1ccc(cc1)[C@@H]2C[N@@H+]([C@@H]3[C@H]2N4CCC3...
# 1  OZD  ZINC000040149497  c1ccc(cc1)N2CC[NH+](CC2)C/C(=[NH+]/OCC(=O)NCc3...
#
#       dd_ABC   dd_ABCGG  dd_nAcid  dd_nBase  dd_SpAbs_A  dd_SpMax_A  \
# 0  22.494165  16.342575       0.0       3.0   37.887760    2.578878
# 1  22.208040  15.742774       0.0       3.0   37.409843    2.317886
#
#    dd_SpDiam_A  ...   dd_SRW10  dd_TSRW10      dd_MW    dd_AMW  dd_WPath  \
# 0     5.044375  ...  10.458378  78.308840  377.28200  5.988603    2056.0
# 1     4.635773  ...   9.928814  63.701084  417.19205  7.319159    3030.0
#
#    dd_WPol  dd_Zagreb1  dd_Zagreb2  dd_mZagreb1  dd_mZagreb2
# 0     46.0       156.0       189.0     7.111111     6.083334
# 1     38.0       142.0       158.0     8.527778     6.527778
#
# [2 rows x 1829 columns]

# %% [markdown]
# # Agg all fea files to single file

# %%
# dfs = []
# dd0 = pd.read_csv( Path(fea_files[0]), names=cols )
# dd1 = pd.read_csv( Path(fea_files[1]), names=cols )
# dfs.append(dd0)
# dfs.append(dd1)
# df = pd.concat(dfs, axis=0).shape
# sizeof(dfs[0])*600

# %%
df = None
t0 = time()
dfs = []

for i, f in enumerate(fea_files[:100]):
    print(f'Loading {i+1} ... {f}')
    dd = pd.read_csv( Path(fea_files[0]), names=cols )
    # print(sizeof(dd));
    dfs.append(dd)
    
runtime = time() - t0
print('\nRuntime: {:.2f} mins'.format( runtime/60 ))
# Out:
# Loading 1 ... /vol/ml/apartin/projects/covid-19/mol-features/data/raw/OZD-Kyle/descriptors/OZD-0-10000.csv
# Loading 2 ... /vol/ml/apartin/projects/covid-19/mol-features/data/raw/OZD-Kyle/descriptors/OZD-10000-20000.csv
# Loading 3 ... /vol/ml/apartin/projects/covid-19/mol-features/data/raw/OZD-Kyle/descriptors/OZD-100000-110000.csv
# Loading 4 ... /vol/ml/apartin/projects/covid-19/mol-features/data/raw/OZD-Kyle/descriptors/OZD-1000000-1010000.csv
# Loading 5 ... /vol/ml/apartin/projects/covid-19/mol-features/data/raw/OZD-Kyle/descriptors/OZD-1010000-1020000.csv
# Loading 6 ... /vol/ml/apartin/projects/covid-19/mol-features/data/raw/OZD-Kyle/descriptors/OZD-1020000-1030000.csv
# Loading 7 ... /vol/ml/apartin/projects/covid-19/mol-features/data/raw/OZD-Kyle/descriptors/OZD-1030000-1040000.csv
# Loading 8 ... /vol/ml/apartin/projects/covid-19/mol-features/data/raw/OZD-Kyle/descriptors/OZD-1040000-1050000.csv
# Loading 9 ... /vol/ml/apartin/projects/covid-19/mol-features/data/raw/OZD-Kyle/descriptors/OZD-1050000-1060000.csv
# Loading 10 ... /vol/ml/apartin/projects/covid-19/mol-features/data/raw/OZD-Kyle/descriptors/OZD-1060000-1070000.csv
# Loading 11 ... /vol/ml/apartin/projects/covid-19/mol-features/data/raw/OZD-Kyle/descriptors/OZD-1070000-1080000.csv
# Loading 12 ... /vol/ml/apartin/projects/covid-19/mol-features/data/raw/OZD-Kyle/descriptors/OZD-1080000-1090000.csv
# Loading 13 ... /vol/ml/apartin/projects/covid-19/mol-features/data/raw/OZD-Kyle/descriptors/OZD-1090000-1100000.csv
# Loading 14 ... /vol/ml/apartin/projects/covid-19/mol-features/data/raw/OZD-Kyle/descriptors/OZD-110000-120000.csv
# Loading 15 ... /vol/ml/apartin/projects/covid-19/mol-features/data/raw/OZD-Kyle/descriptors/OZD-1100000-1110000.csv
# Loading 16 ... /vol/ml/apartin/projects/covid-19/mol-features/data/raw/OZD-Kyle/descriptors/OZD-
... /vol/ml/apartin/projects/covid-19/mol-features/data/raw/OZD-Kyle/descriptors/OZD-1870000-1880000.csv
# Loading 100 ... /vol/ml/apartin/projects/covid-19/mol-features/data/raw/OZD-Kyle/descriptors/OZD-1880000-1890000.csv
#
# Runtime: 4.63 mins

# %%
fea_df = pd.concat(dfs, axis=0)
print(fea_df.shape)
print(sizeof(fea_df));
# Out:
# (1000000, 1829)
# Size in GB: 14.861525632
# 14.861525632

# %% [markdown]
# # Load docking scores

# %%
# meta_path = Path('/vol/ml/apartin/projects/covid-19/mol-features/nbs/OZD.May29.all.csv')
dock_main_dir = Path('/vol/ml/apartin/projects/covid-19/mol-features/data/raw/docking-2020-06-01/all/OZD')
dock = pd.read_csv(dock_main_dir/'3CLPro_7BQY_A_1_F.Orderable_zinc_db_enaHLL.sorted.4col.csv')
print(dock.shape)
display(dock[:2])
# Out:
# (6109329, 4)
#                      Inchi-key  \
# 0  MQQAVNHQRUNOBV-SDHOMARFSA-P
# 1  DGLCKPUNCXSIDP-UHFFFAOYSA-P
#
#                                               SMILES             TITLE  \
# 0  Cc1ccc(cc1)[C@@H]2C[N@@H+]([C@@H]3[C@H]2N4CCC3...  ZINC000095370606
# 1  c1ccc(cc1)N2CC[NH+](CC2)C/C(=[NH+]/OCC(=O)NCc3...  ZINC000040149497
#
#    Chemgauss4
# 0  -15.272850
# 1  -14.439569

# %%
dd_trg = pd.merge(dock, fea_df, how='inner', on=['TITLE', 'SMILES'])
print(dd_trg.shape)
print(sizeof(dd_trg));
display(dd_trg[:2])
# Out:
# (1000000, 1831)
# Size in GB: 14.953525632
# 14.953525632
#                      Inchi-key  \
# 0  MQQAVNHQRUNOBV-SDHOMARFSA-P
# 1  MQQAVNHQRUNOBV-SDHOMARFSA-P
#
#                                               SMILES             TITLE  \
# 0  Cc1ccc(cc1)[C@@H]2C[N@@H+]([C@@H]3[C@H]2N4CCC3...  ZINC000095370606
# 1  Cc1ccc(cc1)[C@@H]2C[N@@H+]([C@@H]3[C@H]2N4CCC3...  ZINC000095370606
#
#    Chemgauss4  CAT     dd_ABC   dd_ABCGG  dd_nAcid  dd_nBase  dd_SpAbs_A  ...  \
# 0   -15.27285  OZD  22.494165  16.342575       0.0       3.0    37.88776  ...
# 1   -15.27285  OZD  22.494165  16.342575       0.0       3.0    37.88776  ...
#
#     dd_SRW10  dd_TSRW10    dd_MW    dd_AMW  dd_WPath  dd_WPol  dd_Zagreb1  \
# 0  10.458378   78.30884  377.282  5.988603    2056.0     46.0       156.0
# 1  10.458378   78.30884  377.282  5.988603    2056.0     46.0       156.0
#
#    dd_Zagreb2  dd_mZagreb1  dd_mZagreb2
# 0       189.0     7.111111     6.083334
# 1       189.0     7.111111     6.083334
#
# [2 rows x 1831 columns]

# %%
meta_cols = ['CAT', 'Inchi-key', 'SMILES', 'TITLE', 'Chemgauss4']
dd_trg = dd_trg[ meta_cols + fea_col_names ]
print(dd_trg.shape)
print(sizeof(dd_trg));
display(dd_trg[:2])
# Out:
# (1000000, 1831)
# Size in GB: 14.953525632
# 14.953525632
#    CAT                    Inchi-key  \
# 0  OZD  MQQAVNHQRUNOBV-SDHOMARFSA-P
# 1  OZD  MQQAVNHQRUNOBV-SDHOMARFSA-P
#
#                                               SMILES             TITLE  \
# 0  Cc1ccc(cc1)[C@@H]2C[N@@H+]([C@@H]3[C@H]2N4CCC3...  ZINC000095370606
# 1  Cc1ccc(cc1)[C@@H]2C[N@@H+]([C@@H]3[C@H]2N4CCC3...  ZINC000095370606
#
#    Chemgauss4     dd_ABC   dd_ABCGG  dd_nAcid  dd_nBase  dd_SpAbs_A  ...  \
# 0   -15.27285  22.494165  16.342575       0.0       3.0    37.88776  ...
# 1   -15.27285  22.494165  16.342575       0.0       3.0    37.88776  ...
#
#     dd_SRW10  dd_TSRW10    dd_MW    dd_AMW  dd_WPath  dd_WPol  dd_Zagreb1  \
# 0  10.458378   78.30884  377.282  5.988603    2056.0     46.0       156.0
# 1  10.458378   78.30884  377.282  5.988603    2056.0     46.0       156.0
#
#    dd_Zagreb2  dd_mZagreb1  dd_mZagreb2
# 0       189.0     7.111111     6.083334
# 1       189.0     7.111111     6.083334
#
# [2 rows x 1831 columns]

# %%
dd_trg.shape
# Out:
# (1000000, 1831)

# %%
dd_trg
# Out:
#         CAT                    Inchi-key  \
# 0       OZD  MQQAVNHQRUNOBV-SDHOMARFSA-P
# 1       OZD  MQQAVNHQRUNOBV-SDHOMARFSA-P
# 2       OZD  MQQAVNHQRUNOBV-SDHOMARFSA-P
# 3       OZD  MQQAVNHQRUNOBV-SDHOMARFSA-P
# 4       OZD  MQQAVNHQRUNOBV-SDHOMARFSA-P
# ...     ...                          ...
# 999995  OZD  SJTOMVPZRFLKOA-NHCUHLMSSA-P
# 999996  OZD  SJTOMVPZRFLKOA-NHCUHLMSSA-P
# 999997  OZD  SJTOMVPZRFLKOA-NHCUHLMSSA-P
# 999998  OZD  SJTOMVPZRFLKOA-NHCUHLMSSA-P
# 999999  OZD  SJTOMVPZRFLKOA-NHCUHLMSSA-P
#
#                                                    SMILES             TITLE  \
# 0       Cc1ccc(cc1)[C@@H]2C[N@@H+]([C@@H]3[C@H]2N4CCC3...  ZINC000095370606
# 1       Cc1ccc(cc1)[C@@H]2C[N@@H+]([C@@H]3[C@H]2N4CCC3...  ZINC000095370606
# 2       Cc1ccc(cc1)[C@@H]2C[N@@H+]([C@@H]3[C@H]2N4CCC3...  ZINC000095370606
# 3       Cc1ccc(cc1)[C@@H]2C[N@@H+]([C@@H]3[C@H]2N4CCC3...  ZINC000095370606
# 4       Cc1ccc(cc1)[C@@H]2C[N@@H+]([C@@H]3[C@H]2N4CCC3...  ZINC000095370606
# ...                                                   ...               ...
# 999995  C[NH+](C)C[C@@H]1C[N@@H+](C[C@@H]1CO)Cc2cnn(c2...  ZINC000091656771
# 999996  C[NH+](C)C[C@@H]1C[N@@H+](C[C@@H]1CO)Cc2cnn(c2...  ZINC000091656771
# 999997  C[NH+](C)C[C@@H]1C[N@@H+](C[C@@H]1CO)Cc2cnn(c2...  ZINC000091656771
# 999998  C[NH+](C)C[C@@H]1C[N@@H+](C[C@@H]1CO)Cc2cnn(c2...  ZINC000091656771
# 999999  C[NH+](C)C[C@@H]1C[N@@H+](C[C@@H]1CO)Cc2cnn(c2...  ZINC000091656771
#
#         Chemgauss4     dd_ABC   dd_ABCGG  dd_nAcid  dd_nBase  dd_SpAbs_A  ...  \
# 0       -15.272850  22.494165  16.342575       0.0       3.0   37.887760  ...
# 1       -15.272850  22.494165  16.342575       0.0       3.0   37.887760  ...
# 2       -15.272850  22.494165  16.342575       0.0       3.0   37.887760  ...
# 3       -15.272850  22.494165  16.342575       0.0       3.0   37.887760  ...
# 4       -15.272850  22.494165  16.342575       0.0       3.0   37.887760  ...
# ...            ...        ...        ...       ...       ...         ...  ...
# 999995  -11.771907  21.310663  16.290300       0.0       2.0   35.373165  ...
# 999996  -11.771907  21.310663  16.290300       0.0       2.0   35.373165  ...
# 999997  -11.771907  21.310663  16.290300       0.0       2.0   35.373165  ...
# 999998  -11.771907  21.310663  16.290300       0.0       2.0   35.373165  ...
# 999999  -11.771907  21.310663  16.290300       0.0       2.0   35.373165  ...
#
#          dd_SRW10  dd_TSRW10      dd_MW    dd_AMW  dd_WPath  dd_WPol  \
# 0       10.458378   78.30884  377.28200  5.988603    2056.0     46.0
# 1       10.458378   78.30884  377.28200  5.988603    2056.0     46.0
# 2       10.458378   78.30884  377.28200  5.988603    2056.0     46.0
# 3       10.458378   78.30884  377.28200  5.988603    2056.0     46.0
# 4       10.458378   78.30884  377.28200  5.988603    2056.0     46.0
# ...           ...        ...        ...       ...       ...      ...
# 999995  10.148040   77.93240  366.24088  6.425278    2086.0     39.0
# 999996  10.148040   77.93240  366.24088  6.425278    2086.0     39.0
# 999997  10.148040   77.93240  366.24088  6.425278    2086.0     39.0
# 999998  10.148040   77.93240  366.24088  6.425278    2086.0     39.0
# 999999  10.148040   77.93240  366.24088  6.425278    2086.0     39.0
#
#         dd_Zagreb1  dd_Zagreb2  dd_mZagreb1  dd_mZagreb2
# 0            156.0       189.0     7.111111     6.083334
# 1            156.0       189.0     7.111111     6.083334
# 2            156.0       189.0     7.111111     6.083334
# 3            156.0       189.0     7.111111     6.083334
# 4            156.0       189.0     7.111111     6.083334
# ...            ...         ...          ...          ...
# 999995       144.0       169.0     7.750000     5.916666
# 999996       144.0       169.0     7.750000     5.916666
# 999997       144.0       169.0     7.750000     5.916666
# 999998       144.0       169.0     7.750000     5.916666
# 999999       144.0       169.0     7.750000     5.916666
#
# [1000000 rows x 1831 columns]
